# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\SHAIKH\\Desktop\\analyticsmile\\Pune_property_data.csv")
df.head()
# Out:
#    Unnamed: 0 additionalrooms          age  \
# 0           0             NaN  2 - 3 years
# 1           1             NaN   0 - 1 year
# 2           2             NaN   0 - 1 year
# 3           3             NaN  2 - 3 years
# 4           4             NaN   0 - 1 year
#
#                                   amenitiesavailable  \
# 0  Lift Available,Car Parking,Power Backup,Indoor...
# 1  Lift Available,Car Parking,Power Backup,24 X 7...
# 2  Lift Available,Car Parking,Power Backup,24 X 7...
# 3  Lift Available,Car Parking,Power Backup,24 X 7...
# 4  Lift Available,Car Parking,Power Backup,24 X 7...
#
#                                         amenitiesnot         area balconies  \
# 0  24 X 7 Security,Children's play area,Club Hous...  1,611 sq ft         2
# 1  Children's play area,Sports Facility,Landscape...  1,279 sq ft       NaN
# 2                                    Sports Facility    670 sq ft       NaN
# ...

# %%
df["area"]
# Out:
# 0        1,611 sq ft
# 1        1,279 sq ft
# 2          670 sq ft
# 3          956 sq ft
# 4        1,706 sq ft
#             ...
# 37534    1,084 sq ft
# 37535      953 sq ft
# 37536    1,218 sq ft
# 37537    1,074 sq ft
# 37538    4,561 sq ft
# Name: area, Length: 37539, dtype: object

# %%
int(''.join(filter(str.isdigit, '1,706 sq ft')))
# Out:
# 1706

# %%
df['area']=df['area'].astype(str)

# %%
df1 = df.copy()

# %%
df1["area"] = [element.split(" ")[0] for element in df['area']]

# %%
df1["area"]
# Out:
# 0        1,611
# 1        1,279
# 2          670
# 3          956
# 4        1,706
#          ...
# 37534    1,084
# 37535      953
# 37536    1,218
# 37537    1,074
# 37538    4,561
# Name: area, Length: 37539, dtype: object

# %%
df1["area"]=[element.replace(",","") for element in df1['area']]

# %%
df1["area"]
# Out:
# 0        1611
# 1        1279
# 2         670
# 3         956
# 4        1706
#          ...
# 37534    1084
# 37535     953
# 37536    1218
# 37537    1074
# 37538    4561
# Name: area, Length: 37539, dtype: object

# %%
df1['area'].convert_dtypes(int)
# Out:
# 0        1611
# 1        1279
# 2         670
# 3         956
# 4        1706
#          ...
# 37534    1084
# 37535     953
# 37536    1218
# 37537    1074
# 37538    4561
# Name: area, Length: 37539, dtype: string

# %%
df1['area']=pd.to_numeric(df1.area, errors="coerce")

# %%
df["area"]
# Out:
# 0        1611.0
# 1        1279.0
# 2         670.0
# 3         956.0
# 4        1706.0
#           ...
# 37534    1084.0
# 37535     953.0
# 37536    1218.0
# 37537    1074.0
# 37538    4561.0
# Name: area, Length: 37539, dtype: float64

# %%
df1.head()
# Out:
#    Unnamed: 0 additionalrooms          age  \
# 0           0             NaN  2 - 3 years
# 1           1             NaN   0 - 1 year
# 2           2             NaN   0 - 1 year
# 3           3             NaN  2 - 3 years
# 4           4             NaN   0 - 1 year
#
#                                   amenitiesavailable  \
# 0  Lift Available,Car Parking,Power Backup,Indoor...
# 1  Lift Available,Car Parking,Power Backup,24 X 7...
# 2  Lift Available,Car Parking,Power Backup,24 X 7...
# 3  Lift Available,Car Parking,Power Backup,24 X 7...
# 4  Lift Available,Car Parking,Power Backup,24 X 7...
#
#                                         amenitiesnot    area balconies  \
# 0  24 X 7 Security,Children's play area,Club Hous...  1611.0         2
# 1  Children's play area,Sports Facility,Landscape...  1279.0       NaN
# 2                                    Sports Facility   670.0       NaN
# 3                 Sports Facility,Landscaped Gardens   956.0       NaN
# ...

# %%
df1.dtypes
# Out:
# Unnamed: 0              int64
# additionalrooms        object
# age                    object
# amenitiesavailable     object
# amenitiesnot           object
# area                  float64
# balconies              object
# bathroom               object
# bhk                    object
# carpetarea             object
# facing                 object
# floor                  object
# locality               object
# neworold               object
# opensides              object
# overlooking            object
# ownership              object
# possesiondate          object
# price                  object
# pricepersquare         object
# projectname            object
# roadfaceing            object
# status                 object
# totalfloor             object
# dtype: object

# %%
df['area']=df['area'].astype(str)

# %%
df1 = df.copy()
df['area']=df['area'].astype(str)
df1["area"] = [element.split(" ")[0] for element in df['area']]
df1["area"]
df1["area"]=[element.replace(",","") for element in df1['area']]
df1['area']=pd.to_numeric(df1.area, errors="coerce")

# %%
def Clean(x):
    x = x.astype(str)
    x = [i.split(" ")[0] for i in x]
    x = [i.replace(",","") for i in x]
    x = pd.to_numeric(x,errors="coerce")
    return x

# %%
df1["carpetarea"] = Clean(df1["carpetarea"])

# %%
df1.head()
# Out:
#    Unnamed: 0 additionalrooms          age  \
# 0           0             NaN  2 - 3 years
# 1           1             NaN   0 - 1 year
# 2           2             NaN   0 - 1 year
# 3           3             NaN  2 - 3 years
# 4           4             NaN   0 - 1 year
#
#                                   amenitiesavailable  \
# 0  Lift Available,Car Parking,Power Backup,Indoor...
# 1  Lift Available,Car Parking,Power Backup,24 X 7...
# 2  Lift Available,Car Parking,Power Backup,24 X 7...
# 3  Lift Available,Car Parking,Power Backup,24 X 7...
# 4  Lift Available,Car Parking,Power Backup,24 X 7...
#
#                                         amenitiesnot    area balconies  \
# 0  24 X 7 Security,Children's play area,Club Hous...  1611.0         2
# 1  Children's play area,Sports Facility,Landscape...  1279.0       NaN
# 2                                    Sports Facility   670.0       NaN
# 3                 Sports Facility,Landscaped Gardens   956.0       NaN
# ...

# %%
Clean(df1["pricepersquare"])
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
# df1 = df.copy()
df['pricepersquare']=df['pricepersquare'].astype(str)
df1["pricepersquare"] = [element.split(" ") for element in df['pricepersquare']]
df1["pricepersquare"]
# df1["area"]=[element.replace(",","") for element in df1['area']]
# df1['area']=pd.to_numeric(df1.area, errors="coerce")
# Out:
# 0        [₹, 16,759/, sq, ft, ]
# 1         [₹, 5,950/, sq, ft, ]
# 2         [₹, 6,119/, sq, ft, ]
# 3         [₹, 6,000/, sq, ft, ]
# 4        [₹, 17,000/, sq, ft, ]
#                   ...
# 37534     [₹, 7,714/, sq, ft, ]
# 37535     [₹, 6,650/, sq, ft, ]
# 37536     [₹, 6,650/, sq, ft, ]
# 37537     [₹, 7,243/, sq, ft, ]
# 37538    [₹, 10,480/, sq, ft, ]
# Name: pricepersquare, Length: 37539, dtype: object

# %%
df['pricepersquare']=df['pricepersquare'].astype(str)
df1["pricepersquare"]=[element for element in df1['pricepersquare']]
df1["pricepersquare"]
# Out:
# 0        [₹, 16,759/, sq, ft, ]
# 1         [₹, 5,950/, sq, ft, ]
# 2         [₹, 6,119/, sq, ft, ]
# 3         [₹, 6,000/, sq, ft, ]
# 4        [₹, 17,000/, sq, ft, ]
#                   ...
# 37534     [₹, 7,714/, sq, ft, ]
# 37535     [₹, 6,650/, sq, ft, ]
# 37536     [₹, 6,650/, sq, ft, ]
# 37537     [₹, 7,243/, sq, ft, ]
# 37538    [₹, 10,480/, sq, ft, ]
# Name: pricepersquare, Length: 37539, dtype: object
