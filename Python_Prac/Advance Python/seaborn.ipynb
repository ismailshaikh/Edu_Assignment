# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.pairplot(df,hue="species")

# %%
# Multivariate 
sns.displot(df["petal_length"],hist=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Multivariate
# ----> 2 sns.displot(df["petal_length"],hist=False)
#
# File c:\Users\SHAIKH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2210, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2207 if p.univariate:
#    2209     _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2210     p.plot_univariate_histogram(**hist_kws)
#    2212 else:
#    2214     _assign_default_kwargs(hist_kws, p.plot_bivariate_histogram, histplot)
#
# ...

# %%
# Bivariate
sns.scatterplot(df,x="sepal_length",y="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(df,x="petal_length",y="petal_width")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
corr_matr= df.corr()
corr_matr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(corr_matr)
# Out:
# <AxesSubplot:>

# %%
df.iloc[:,:-1]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.heatmap(df.iloc[:,:-1])
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(df,x = "sepal_length",y = "sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(df,x = "s_length",y = "sepal_width")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sns.lineplot(df,x = "s_length",y = "sepal_width")
#
# File c:\Users\SHAIKH\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
#     620     estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     621     sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     622     legend=legend,
#     623 )
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Univariate 
plt.plot(df["sepal_length"])
plt.xlabel("sepal_length",fontweight='bold')
plt.ylabel("frequency",fontweight='bold')
# Out:
# Text(0, 0.5, 'frequency')

# %%
# # plt.scatter(df['total_profit'],df["month_number"])

# plt.figure(facecolor='grey')
# ax = plt.axes()
# ax.set_facecolor("black")
# plt.plot(df["petal_length"],df['petal_width'], linewidth = 4,linestyle = "dotted",c = "pink",marker = "o")
# plt.xlabel("months",fontweight='bold')
# plt.ylabel("profit",fontweight='bold')
# plt.title("total_profit by month",fontweight='bold')

# %%
# plt.figure(facecolor='grey')
# ax = plt.axes()
# ax.set_facecolor("black")
# plt.plot(df["sepal_length"], linewidth = 2,linestyle = "dotted",c = "r",marker = "o")
# plt.plot(df["petal_length"], linewidth = 2,linestyle = "dotted",c = "b",marker = "o")
# plt.plot(df["sepal_width"], linewidth = 2,linestyle = "dotted",c = "y",marker = "o")
# plt.plot(df["petal_width"], linewidth = 2,linestyle = "dotted",c = "pink",marker = "o")
# plt.xlabel("flower",fontweight='bold')
# plt.ylabel("Products",fontweight='bold')
# plt.title("product Monthly sales trend",fontweight='bold')

# %%
plt.figure(facecolor='grey')
ax = plt.axes()
ax.set_facecolor("black")
plt.scatter(df["petal_length"],df['petal_width'],marker="*",color = "green")
plt.xlabel("petal_length",fontweight='bold')
plt.ylabel("petal_width",fontweight='bold')
plt.title("petal_length vs petal_width ",fontweight='bold')
# Out:
# Text(0.5, 1.0, 'petal_length vs petal_width ')

# %%
# plt.scatter(df["facewash"],df['facecream'])
plt.subplot(1,2,1)
# plt.bar(df["facewash"],df['facecream'])
plt.hist(df["petal_length"])

plt.subplot(1,2,2)
plt.hist(df['petal_width'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
# # plot 1
# plt.figure(figsize=(8, 4),facecolor='grey')
# plt.subplot(1,2,1)

# ax = plt.axes()
# ax.set_facecolor("black")
# plt.scatter(x_test,y_test,color = 'r',marker="*")
# plt.grid()
# plt.xlabel('Area in sqft')
# plt.ylabel("Price")
# plt.title("Area vs Price Distribution")

# # plot 2
# plt.figure(figsize=(8, 4),facecolor='grey')
# plt.subplot(1,2,2)

# ax = plt.axes()
# ax.set_facecolor("black")
# plt.scatter(x_test,y_test,color = 'r',marker="h")
# plt.plot(x_test,y_pred,linestyle = 'dotted',linewidth = 4,c = "green")
# plt.grid()
# plt.xlabel('Area in sqft',fontweight='bold')
# plt.ylabel("Price",fontweight='bold')
# plt.title("Area vs Price Distribution",fontweight='bold')

# plt.show()

# %%
plt.boxplot(df.iloc[:,:-1])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b5a9a55f00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b5a9a564a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b5a9a55c30>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1b5a9a56a40>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1b5a9a56d10>,
# ...
#  'means': []}

# %%
sns.boxplot(df['sepal_length'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['sepal_width'])
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

# %%
df1 = pd.read_csv("C:\\Users\\SHAIKH\\Desktop\\practice\\campusx\\titanic.csv")

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.boxenplot(df1,x = "Sex", y="Fare",hue="Survived")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
# !pip install pandas_profiling
# Out:
# ...
#   Using cached pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/324.4 kB ? eta -:--:--
#      ----------------------------------- -- 307.2/324.4 kB 9.6 MB/s eta 0:00:01
#      ------------------------------------- 324.4/324.4 kB 10.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/356.3 kB ? eta -:--:--
#      ------------------------------------- 356.3/356.3 kB 10.8 MB/s eta 0:00:00
# ...
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/296.5 kB ? eta -:--:--
#      -------------------------------------- 296.5/296.5 kB 9.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
# ...

# %%
from pandas_profiling import ProfileReport
# Out:
# C:\Users\SHAIKH\AppData\Local\Temp\ipykernel_2572\3063248848.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-08-08 15:17:09.695947&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df1.plot()
# Out:
# <AxesSubplot:>
